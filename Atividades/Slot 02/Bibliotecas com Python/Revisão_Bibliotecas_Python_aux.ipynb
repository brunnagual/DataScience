# %% [markdown]
# Basket

# %%
times = [
  'Boston Celtics',
  'Golden State',
  'Los Angeles Lakers'
]

# %%
import esportes

# %%
esportes
# Out:
# <module 'esportes' from '/content/esportes.py'>

# %%
dir(esportes)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'cria_partidas',
#  'filtra_partida']

# %%
def cria_partidas():
  print('Estou no programa do basket')

# %%
cria_partidas()
# Out:
# Estou no programa do basket

# %%
esportes.cria_partidas(times)
# Out:
# vim do programa do futebol
# [('Boston Celtics', 'Golden State'),
#  ('Boston Celtics', 'Los Angeles Lakers'),
#  ('Golden State', 'Boston Celtics'),
#  ('Golden State', 'Los Angeles Lakers'),
#  ('Los Angeles Lakers', 'Boston Celtics'),
#  ('Los Angeles Lakers', 'Golden State')]

# %%
from esportes import filtra_partida

# %%
pontos = 10
pontos = 20
pontos
pontos = 10

# %%
filtra_partida
# Out:
# <function esportes.filtra_partida>

# %%
import esportes as es

# %%
es.filtra_partida
# Out:
# <function esportes.filtra_partida>

# %%
from esportes import print as print_esportes

# %%
print_esportes('Ola Mundo')
# Out:
# 'Estou no programa do basket'

# %%
print('Ola Mundo')
# Out:
# Ola Mundo

# %%
print
# Out:
# <function __main__.print>

# %%
filtra_partida
# Out:
# <function __main__.filtra_partida>

# %%
esportes.cria_partidas(times)
# Out:
# vim do programa do futebol
# [('Boston Celtics', 'Golden State'),
#  ('Boston Celtics', 'Los Angeles Lakers'),
#  ('Golden State', 'Boston Celtics'),
#  ('Golden State', 'Los Angeles Lakers'),
#  ('Los Angeles Lakers', 'Boston Celtics'),
#  ('Los Angeles Lakers', 'Golden State')]

# %%
esportes.filtra_partida
# Out:
# <function esportes.filtra_partida>
